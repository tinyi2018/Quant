# %%
import tushare as ts
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib as ta

# %% [markdown]
# pro = ts.pro_api('af5f423bb57f376e71c2903058362f8e3e053fe30f486463f9bdac8e')

# %% [markdown]
# ts_list = '601700.SH'
# df = pro.daily(ts_code=ts_list, start_date='20220616', end_date='20220707')

# %%
df = pd.read_csv("new.csv")

# %%
df
# Out:
#       trade_date   open   high    low  close  pre_close  change  pct_chg  \
# 0       20120618  46.48  46.70  45.62  46.12      46.06    0.06   0.1300
# 1       20120619  46.00  46.60  45.85  45.96      46.12   -0.16  -0.3500
# 2       20120620  46.00  46.54  45.95  46.04      45.96    0.08   0.1700
# 3       20120621  45.76  45.76  44.26  44.77      46.04   -1.27  -2.7600
# 4       20120625  44.45  44.59  43.47  43.54      44.77   -1.23  -2.7500
# ...          ...    ...    ...    ...    ...        ...     ...      ...
# 2438    20220701  46.70  46.98  46.12  46.31      46.69   -0.38  -0.8139
# 2439    20220704  46.20  46.50  45.80  46.46      46.31    0.15   0.3239
# 2440    20220705  46.48  47.55  46.38  46.61      46.46    0.15   0.3229
# 2441    20220706  46.62  46.63  45.75  45.85      46.61   -0.76  -1.6306
# 2442    20220707  45.65  46.14  45.59  45.60      45.85   -0.25  -0.5453
#
#             vol       amount     ma5    ma10  ma5>ma10  ma5>ma10_pre     jc
# 0     201148.87   928630.635  45.286  45.251      True         False  False
# 1     202791.28   938135.164  45.286  45.251      True         False  False
# 2     138919.49   641604.885  45.286  45.251      True         False  False
# 3     275213.40  1234013.462  45.286  45.251      True         False  False
# 4     189097.16   831236.799  45.286  45.251      True         False  False
# ...         ...          ...     ...     ...       ...           ...    ...
# 2438  357568.42  1657492.966  46.698  46.339      True         False   True
# 2439  407129.60  1877564.069  46.630  46.449      True         False   True
# 2440  452568.50  2123843.409  46.572  46.497      True         False   True
# 2441  389560.93  1790455.442  46.384  46.542     False         False  False
# 2442  293722.10  1344724.700  46.166  46.477     False         False  False
#
# [2443 rows x 15 columns]

# %%
close = df.close
ma5 = ta.MA(close, 5 , 0)
ma5
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4       45.286
#          ...
# 2438    46.698
# 2439    46.630
# 2440    46.572
# 2441    46.384
# 2442    46.166
# Length: 2443, dtype: float64

# %%
bl = ta.BBANDS(close)
bl
# Out:
# (0             NaN
#  1             NaN
#  2             NaN
#  3             NaN
#  4       47.292613
#            ...
#  2438    47.108151
#  2439    47.062111
#  2440    46.911506
#  2441    46.978051
#  2442    46.927325
#  Length: 2443, dtype: float64,
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4       45.286
#           ...
#  2438    46.698
#  2439    46.630
#  2440    46.572
#  2441    46.384
#  2442    46.166
#  Length: 2443, dtype: float64,
#  0             NaN
#  1             NaN
#  2             NaN
#  3             NaN
#  4       43.279387
#            ...
#  2438    46.287849
#  2439    46.197889
#  2440    46.232494
#  2441    45.789949
#  2442    45.404675
#  Length: 2443, dtype: float64)

# %%
plt.plot(bl[0])
plt.plot(bl[1])
plt.plot(bl[2])
